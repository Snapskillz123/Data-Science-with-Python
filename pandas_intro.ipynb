# %% [markdown]
# # Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# # Reading a csv file

# %%
df=pd.read_csv("pokemon_data.csv")
df
# I saved the csv file in the same directory coz i was having file path issues
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# # Obtaining basic statistical data

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df["HP"].max()
# Same for min
# Out:
# 255

# %%
df.head()
# Prints first 5 rows by default
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.tail(3)
# Prints last 3 rows
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df[18:25]
# Prints a custom range of rows
# Out:
#      #                   Name  Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 18  15               Beedrill     Bug  Poison  65      90       40       45
# 19  15  BeedrillMega Beedrill     Bug  Poison  65     150       40       15
# 20  16                 Pidgey  Normal  Flying  40      45       40       35
# 21  17              Pidgeotto  Normal  Flying  63      60       55       50
# 22  18                Pidgeot  Normal  Flying  83      80       75       70
# 23  18    PidgeotMega Pidgeot  Normal  Flying  83      80       80      135
# 24  19                Rattata  Normal     NaN  30      56       35       25
#
#     Sp. Def  Speed  Generation  Legendary
# 18       80     75           1      False
# 19       80    145           1      False
# 20       35     56           1      False
# 21       50     71           1      False
# 22       70    101           1      False
# 23       80    121           1      False
# 24       35     72           1      False

# %%
df.iloc[7]
# Prints the 7th row
# Out:
# #                                     6
# Name          CharizardMega Charizard X
# Type 1                             Fire
# Type 2                           Dragon
# HP                                   78
# Attack                              130
# Defense                             111
# Sp. Atk                             130
# Sp. Def                              85
# Speed                               100
# Generation                            1
# Legendary                         False
# Name: 7, dtype: object

# %% [markdown]
# # Selecting rows based on specific info

# %%
df.loc[df["Type 1"]=="Water"]
# Prints all type 1 pokemons that are Water type
# Out:
#        #                     Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 9      7                 Squirtle  Water    NaN  44      48       65       50
# 10     8                Wartortle  Water    NaN  59      63       80       65
# 11     9                Blastoise  Water    NaN  79      83      100       85
# 12     9  BlastoiseMega Blastoise  Water    NaN  79     103      120      135
# 59    54                  Psyduck  Water    NaN  50      52       48       65
# ..   ...                      ...    ...    ...  ..     ...      ...      ...
# 724  656                  Froakie  Water    NaN  41      56       40       62
# 725  657                Frogadier  Water    NaN  54      63       52       83
# 726  658                 Greninja  Water   Dark  72      95       67      103
# 762  692                Clauncher  Water    NaN  50      53       62       58
# 763  693                Clawitzer  Water    NaN  71      73       88      120
#
# ...

# %%
df.loc[df["Generation"]<=2]
# Prints pokemons who are from first and second generation
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 0      1                Bulbasaur    Grass  Poison   45      49       49
# 1      2                  Ivysaur    Grass  Poison   60      62       63
# 2      3                 Venusaur    Grass  Poison   80      82       83
# 3      3    VenusaurMega Venusaur    Grass  Poison   80     100      123
# 4      4               Charmander     Fire     NaN   39      52       43
# ..   ...                      ...      ...     ...  ...     ...      ...
# 267  248                Tyranitar     Rock    Dark  100     134      110
# 268  248  TyranitarMega Tyranitar     Rock    Dark  100     164      150
# 269  249                    Lugia  Psychic  Flying  106      90      130
# 270  250                    Ho-oh     Fire  Flying  106     130       90
# 271  251                   Celebi  Psychic   Grass  100     100      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Sorting Data

# %%
df.sort_values("HP")
# Prints HP values in ascending order as that is the default order
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja      Bug  Ghost    1      90       45       30       30
# 55    50    Diglett   Ground    NaN   10      55       25       35       45
# 139  129   Magikarp    Water    NaN   20      10       55       15       20
# 388  355    Duskull    Ghost    NaN   20      40       90       30       90
# 487  439   Mime Jr.  Psychic  Fairy   20      25       45       70       90
# ..   ...        ...      ...    ...  ...     ...      ...      ...      ...
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
#
#      Speed  Generation  Legendary
# ...

# %%
df.sort_values("HP",ascending=False)
# Prints HP in descending order
# Out:
#        #       Name   Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 261  242    Blissey   Normal    NaN  255      10       10       75      135
# 121  113    Chansey   Normal    NaN  250       5        5       35      105
# 217  202  Wobbuffet  Psychic    NaN  190      33       58       33       58
# 351  321    Wailord    Water    NaN  170      90       45       90       45
# 655  594  Alomomola    Water    NaN  165      75       80       40       45
# ..   ...        ...      ...    ...  ...     ...      ...      ...      ...
# 139  129   Magikarp    Water    NaN   20      10       55       15       20
# 381  349     Feebas    Water    NaN   20      15       20       10       55
# 388  355    Duskull    Ghost    NaN   20      40       90       30       90
# 55    50    Diglett   Ground    NaN   10      55       25       35       45
# 316  292   Shedinja      Bug  Ghost    1      90       45       30       30
#
#      Speed  Generation  Legendary
# ...

# %%
df.sort_values(["Generation","Attack"])
# Sorts the values first based on the generation, then among that generation it sorts it based on lowest attack to highest attack.
# Out:
#        #                  Name   Type 1  Type 2   HP  Attack  Defense  \
# 121  113               Chansey   Normal     NaN  250       5        5
# 139  129              Magikarp    Water     NaN   20      10       55
# 14    11               Metapod      Bug     NaN   50      20       55
# 68    63                  Abra  Psychic     NaN   25      20       15
# 17    14                Kakuna      Bug  Poison   45      25       50
# ..   ...                   ...      ...     ...  ...     ...      ...
# 792  716               Xerneas    Fairy     NaN  126     131       95
# 793  717               Yveltal     Dark  Flying  126     131       95
# 750  681  AegislashBlade Forme    Steel   Ghost   60     150       50
# 796  719   DiancieMega Diancie     Rock   Fairy   50     160      110
# 798  720    HoopaHoopa Unbound  Psychic    Dark   80     160       60
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 121       35      105     50           1      False
# ...

# %%
df.sort_values(["Generation","Attack"],ascending=[1,0])
# Sorts Generation in ascending order, and in that generation it sorts the pokemons attack in decending order
# Out:
#        #                   Name    Type 1    Type 2   HP  Attack  Defense  \
# 163  150    MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# 137  127      PinsirMega Pinsir       Bug    Flying   65     155      120
# 141  130  GyaradosMega Gyarados     Water      Dark   95     155      109
# 19    15  BeedrillMega Beedrill       Bug    Poison   65     150       40
# 164  150    MewtwoMega Mewtwo Y   Psychic       NaN  106     150       70
# ..   ...                    ...       ...       ...  ...     ...      ...
# 764  694             Helioptile  Electric    Normal   44      38       33
# 727  659               Bunnelby    Normal       NaN   38      36       38
# 732  664             Scatterbug       Bug       NaN   38      35       40
# 790  714                 Noibat    Flying    Dragon   40      30       35
# 733  665                 Spewpa       Bug       NaN   45      22       60
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
res_df=df.loc[(df["Type 1"]=="Psychic") & (df["Type 2"]=="Fairy")]
#Prints Psychic type pokemons which are fairy type
res_df=res_df.reset_index()
res_df
# reset_index makes the index values according to this specific condition
# Out:
#    index    #                     Name   Type 1 Type 2  HP  Attack  Defense  \
# 0    131  122                 Mr. Mime  Psychic  Fairy  40      45       65
# 1    303  280                    Ralts  Psychic  Fairy  28      25       25
# 2    304  281                   Kirlia  Psychic  Fairy  38      35       35
# 3    305  282                Gardevoir  Psychic  Fairy  68      65       65
# 4    306  282  GardevoirMega Gardevoir  Psychic  Fairy  68      85       65
# 5    487  439                 Mime Jr.  Psychic  Fairy  20      25       45
#
#    Sp. Atk  Speed  Generation  Legendary  All_Round  Sum
# 0      100     90           1      False       55.0  250
# 1       45     40           3      False       25.0  123
# 2       65     50           3      False       35.0  173
# 3      125     80           3      False       65.0  323
# 4      165    100           3      False       75.0  383
# 5       70     60           4      False       35.0  160

# %%
df.loc[df["Name"].str.contains("Char")]
# Prints all rows where the name ofthe pokemon has"Char" in it
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Speed  Generation  Legendary  All_Round  Sum
# 4     65           1      False       47.5  194
# 5     80           1      False       61.0  260
# 6    100           1      False       81.0  349
# 7    100           1      False      120.5  449
# 8    100           1      False       91.0  419

# %%
df["Type 1"].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %% [markdown]
# # Manipulating Data

# %%
df["All_Round"]=(df["Attack"]+df["Defense"])/2 
df
# Creating a new column All_Round that is the average of Attack and Defense
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  All_Round
# 0         65       65     45           1      False       49.0
# ...

# %%
df= df.drop(columns=["Sp. Def"])
df
# Sp. Def column is being removed from the dataframe. Saving the edited DF in the variable is important
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
df["Sum"]= df.iloc[:, 4:8].sum(axis=1)
df
# Creates a new column Sum that adds columns from HP to Sp. Atk for each row and saves that sum in the new Sums column
# iloc is used to locate index values and return the value of that cell as done earlier
# iloc take arguments[row, column]. Over here ':' selects all rows and 4:8 selects columns of those index values.
# .sum() is used for addition and axis=1 makes sure that the addition in horizontal
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Speed  Generation  Legendary  All_Round  Sum
# 0         65     45           1      False       49.0  208
# ...

# %%
df.fillna("Mystery")
# Fills null value with "mystery"
# Out:
#        #                   Name   Type 1   Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass   Poison  45      49       49
# 1      2                Ivysaur    Grass   Poison  60      62       63
# 2      3               Venusaur    Grass   Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass   Poison  80     100      123
# 4      4             Charmander     Fire  Mystery  39      52       43
# ..   ...                    ...      ...      ...  ..     ...      ...
# 795  719                Diancie     Rock    Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock    Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic    Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic     Dark  80     160       60
# 799  721              Volcanion     Fire    Water  80     110      120
#
#      Sp. Atk  Speed  Generation  Legendary  All_Round  Sum
# ...

# %%
df = df.replace(to_replace = 'Grass', value ='Nature')
df
#replaces grass type with nature
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur   Nature  Poison  45      49       49
# 1      2                Ivysaur   Nature  Poison  60      62       63
# 2      3               Venusaur   Nature  Poison  80      82       83
# 3      3  VenusaurMega Venusaur   Nature  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %% [markdown]
# # Statistics

# %%
df=pd.read_csv("pokemon_data.csv")

# %%
df.groupby(['Type 1']).mean(numeric_only=True)
# Sorts Type 1 alphabetically and prints the mean of each numeric column of each row
# Out:
#        #      Name Type 1    Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 600  540  Sewaddle    Bug     Grass   45      53       70       40       60
# 136  127    Pinsir    Bug       NaN   65     125      100       55       70
# 457  412     Burmy    Bug       NaN   40      29       45       29       45
# 132  123   Scyther    Bug    Flying   70     110       80       55       80
# 656  595    Joltik    Bug  Electric   50      47       50       57       50
# ..   ...       ...    ...       ...  ...     ...      ...      ...      ...
# 172  158  Totodile  Water       NaN   50      65       64       44       48
# 610  550  Basculin  Water       NaN   70      92       65       80       55
# 145  134  Vaporeon  Water       NaN  130      65       60      110       95
# 574  515   Panpour  Water       NaN   50      53       48       53       48
# 184  170  Chinchou  Water  Electric   75      38       38       56       56
#
#      Speed  Generation  Legendary
# ...

# %%
df.groupby(['Type 2']).count()
# Out:
#            #  Name  Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 2
# Bug        3     3       3   3       3        3        3        3      3
# Dark      20    20      20  20      20       20       20       20     20
# Dragon    18    18      18  18      18       18       18       18     18
# Electric   6     6       6   6       6        6        6        6      6
# Fairy     23    23      23  23      23       23       23       23     23
# Fighting  26    26      26  26      26       26       26       26     26
# Fire      12    12      12  12      12       12       12       12     12
# Flying    97    97      97  97      97       97       97       97     97
# Ghost     14    14      14  14      14       14       14       14     14
# Grass     25    25      25  25      25       25       25       25     25
# Ground    35    35      35  35      35       35       35       35     35
# Ice       14    14      14  14      14       14       14       14     14
# ...

# %%
df["Defense"].quantile(0.75)
#prints 75%tile of defense column
# Out:
# 90.0

# %%
pd.crosstab(df["Type 1"],df["Generation"])
# creates a crosstabulation of type 1 vs generation
# Out:
# Generation   1   2   3   4   5   6
# Type 1
# Bug         14  12  12  10  18   3
# Dark         0   6   6   3  13   3
# Dragon       3   0  12   4   9   4
# Electric     9   7   5  12   8   3
# Fairy        2   5   0   1   0   9
# Fighting     7   2   5   3   7   3
# Fire        14   8   8   5   9   8
# Flying       0   0   0   0   2   2
# Ghost        4   1   5   7   5  10
# Grass       13   9  13  15  15   5
# Ground       8   3   7   4  10   0
# Ice          2   4   7   3   6   2
# Normal      24  15  18  18  19   4
# Poison      14   1   3   6   2   2
# Psychic     11   7  12   8  14   5
# Rock        10   5   8   6   6   9
# Steel        0   3  12   3   4   5
# Water       31  18  27  13  18   5
